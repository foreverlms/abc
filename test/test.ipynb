# %%
import tensorflow.keras.preprocessing as prep

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
import numpy as np
import pandas as pd

# %%
import random

# %%
import tensorflow as tf

# %%
import torch

# %%
import onnx

# %%
from onnx_tf.backend import prepaare
# Out:
# /opt/anaconda3/envs/d2l/lib/python3.7/site-packages/tensorflow_addons/utils/ensure_tf_install.py:67: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.3.0 and strictly below 2.5.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.0.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   UserWarning,
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-9-2d0815e6e70e> in <module>
# ----> 1 from onnx_tf.backend import prepaare
#
# ...

# %%
part_2_path = "/Users/bob/docs/ByteDance/espresso/part_1.onnx"

# %%
part_2_model = onnx.load(part_2_path)

# %%
part_2_model

# %%
import time

# %%
int(time.time() * 1000)
# Out:
# 1628575796812

# %%
a = tf.constant([
    [
        [
            [1],[1],[1]
        ],
        [
            [2],[2],[2]
        ]
    ]
    ,
        [
        [
            [3],[3],[3]
        ],
        [
            [4],[4],[4]
        ]
    ]
])

# %%
a
# Out:
# <tf.Tensor: shape=(2, 2, 3, 1), dtype=int32, numpy=
# array([[[[1],
#          [1],
#          [1]],
#
#         [[2],
#          [2],
#          [2]]],
#
#
#        [[[3],
#          [3],
#          [3]],
#
#         [[4],
#          [4],
#          [4]]]], dtype=int32)>

# %%
gamma = tf.constant([
    [
        [
            [2],[3],[2]
        ]
    ]
])

# %%
gamma
# Out:
# <tf.Tensor: shape=(1, 1, 3, 1), dtype=int32, numpy=
# array([[[[2],
#          [3],
#          [2]]]], dtype=int32)>

# %%
a*gamma
# Out:
# <tf.Tensor: shape=(2, 2, 3, 1), dtype=int32, numpy=
# array([[[[ 2],
#          [ 3],
#          [ 2]],
#
#         [[ 4],
#          [ 6],
#          [ 4]]],
#
#
#        [[[ 6],
#          [ 9],
#          [ 6]],
#
#         [[ 8],
#          [12],
#          [ 8]]]], dtype=int32)>

# %%
a
# Out:
# <tf.Tensor: shape=(2, 2, 3, 1), dtype=int32, numpy=
# array([[[[1],
#          [1],
#          [1]],
#
#         [[2],
#          [2],
#          [2]]],
#
#
#        [[[3],
#          [3],
#          [3]],
#
#         [[4],
#          [4],
#          [4]]]], dtype=int32)>

# %%
test = tf.random.uniform(shape=(2,2,3,2), minval=1, maxval=5, dtype=tf.int32)

# %%
tf.transpose(test, perm = [3,0,1,2])
# Out:
# <tf.Tensor: shape=(2, 2, 2, 3), dtype=int32, numpy=
# array([[[[4, 2, 4],
#          [4, 2, 4]],
#
#         [[1, 1, 2],
#          [1, 3, 2]]],
#
#
#        [[[3, 3, 2],
#          [1, 4, 3]],
#
#         [[4, 2, 3],
#          [1, 4, 3]]]], dtype=int32)>

# %%
tf.reshape(test, shape=(1,2,2,3))
# Out:
# <tf.Tensor: shape=(1, 2, 2, 3), dtype=int32, numpy=
# array([[[[2, 4, 1],
#          [4, 3, 2]],
#
#         [[3, 1, 1],
#          [4, 2, 4]]]], dtype=int32)>

# %%
import numpy

# %%
data = [
    -0.915259957,
0.611176669,
-4.27415752,
-2.29328966,
-14.4080076,
0.396923482,
-0.807463586,
-1.21548533,
1.08540905,
0.0134548079,
-0.34603706,
0.282633245,
-0.718247294,
-0.529765964,
-0.396382093,
1.12900615,
-0.888921618,
0.152252108,
-1.59450328,
0.435953915,
-0.189245164,
-2.97230315,
0.835833072,
2.05819201,
-0.363298029,
0.263530284,
0.367984384,
0.766388356,
-0.10357853,
0.174043208,
0.00519207632,
3.91023956E-36,
-13.6242762,
-1.58756614,
-0.244740307,
3.34658194,
-0.238025799,
-0.150351256,
0.699682236,
-6.87351561,
0.149567708,
0.404550731,
0.278983235,
11.8062963,
], dtype = tf.float32, shape = (1,1,1,32))

# %%
variance = tf.constant([  52.9916306,
  98.6942443,
  1.07424688,
  3.90845594E-36,
  57.062622,
  296.507599,
  0.411148727,
  3.91267929E-36,
  110.319336,
  26.4148273,
  5.2001071,
  3.91252109E-36,
  3.91761222E-36,
  3.91278261E-36,
  21.3122597,
  70.8626938,
  0.0140138669,
  35.9642715,
  0.0347588137,
  3.91159879E-36,
  13.3438597,
  141.240005,
  10.2351866,
  26.5206547,
  415.62619,
  24.5138931,
  0.232058972,
  87.2247086,
  0.00013200994,
  3.68522573,
  3.7254498,
  4.24222136,
], dtype = tf.float32, shape = (1,1,1,32))

# %%
alpha = scale / tf.math.sqrt(variance + 0.0010000000474974513)

# %%
bias = offset - scale * mean / tf.math.sqrt(variance + 0.0010000000474974513)

# %%
bias
# Out:
# <tf.Tensor: shape=(1, 1, 1, 32), dtype=float32, numpy=
# array([[[[ 1.4336991e+00,  3.9028285e+00, -1.7386989e-01,
#           -1.5118119e-01,  3.1703887e+00,  3.0263109e+00,
#            5.0528866e-01, -2.2501117e-01,  3.5679488e+00,
#            6.9691271e-01,  1.4323549e-01, -3.6347121e-01,
#           -4.3650112e-01, -1.0476636e+00,  2.4979608e+00,
#            2.5446095e+00, -8.4106207e-02,  1.4093676e+00,
#            2.5573995e+00, -1.3595705e+00,  4.9378291e-01,
#            2.5719955e+00,  4.8415661e-03, -1.5413187e+00,
#            3.0955384e+00,  3.0006285e+00, -6.5532923e-03,
#            3.3246429e+00, -5.2548385e-01,  2.1279027e+00,
#           -6.5360355e-01, -5.0509801e+00]]]], dtype=float32)>

# %%
alpha
# Out:
# <tf.Tensor: shape=(1, 1, 1, 32), dtype=float32, numpy=
# array([[[[ 0.10963849,  0.10314579,  0.22634086, 18.4899    ,
#            0.1949603 ,  0.09603638,  0.32295808,  8.025716  ,
#            0.16579953,  0.16577041,  0.12513469,  1.5417764 ,
#           19.590965  , 20.824562  ,  0.10010293,  0.11848979,
#            4.1989236 ,  0.14698507,  1.1974407 , 25.109558  ,
#            0.04843626,  0.10568715,  0.3388922 ,  0.09340779,
#            0.07629511,  0.26300952, -0.20090102,  0.09004723,
#            1.1100543 ,  0.66884154,  0.2641704 ,  0.4004299 ]]]],
#       dtype=float32)>

# %%
weight_tensor * alpha
# Out:
# <tf.Tensor: shape=(1, 3, 3, 32), dtype=float32, numpy=
# array([[[[-1.00347720e-01,  6.30403012e-02, -9.67416465e-01,
#           -4.24026985e+01, -2.80898952e+00,  3.81190963e-02,
#           -2.60776877e-01, -9.75514030e+00,  1.79960310e-01,
#            2.23040907e-03, -4.33012396e-02,  4.35757279e-01,
#           -1.40711575e+01, -1.10321445e+01, -3.96790095e-02,
#            1.33775696e-01, -3.73251390e+00,  2.23787874e-02,
#           -1.90932322e+00,  1.09466105e+01, -9.16632731e-03,
#           -3.14134240e-01,  2.83257306e-01,  1.92251161e-01,
#           -2.77178623e-02,  6.93109706e-02, -7.39284381e-02,
#            2.23805666e-01,  2.05325276e-01, -1.72892416e+00,
#           -2.93114752e-01, -1.88455917e-02],
#          [-7.79164433e-01,  3.70052963e-01, -2.73727894e-01,
#           -5.46324921e+01, -4.62501794e-01,  5.14353588e-02,
#           -2.55675197e-01, -7.76070786e+00,  6.31761014e-01,
#            1.93514138e-01, -2.15610210e-02,  5.86002707e-01,
# ...

# %%
weight_tensor
# Out:
# <tf.Tensor: shape=(1, 3, 3, 32), dtype=float32, numpy=
# array([[[[-9.15259957e-01,  6.11176670e-01, -4.27415752e+00,
#           -2.29328966e+00, -1.44080076e+01,  3.96923482e-01,
#           -8.07463586e-01, -1.21548533e+00,  1.08540905e+00,
#            1.34548079e-02, -3.46037060e-01,  2.82633245e-01,
#           -7.18247294e-01, -5.29765964e-01, -3.96382093e-01,
#            1.12900615e+00, -8.88921618e-01,  1.52252108e-01,
#           -1.59450328e+00,  4.35953915e-01, -1.89245164e-01,
#           -2.97230315e+00,  8.35833073e-01,  2.05819201e+00,
#           -3.63298029e-01,  2.63530284e-01,  3.67984384e-01,
#            2.48542523e+00,  1.84968680e-01, -2.58495331e+00,
#           -1.10956693e+00, -4.70633954e-02],
#          [-7.10666895e+00,  3.58766937e+00, -1.20936143e+00,
#           -2.95472074e+00, -2.37228703e+00,  5.35582006e-01,
#           -7.91666806e-01, -9.66980159e-01,  3.81039095e+00,
#            1.16736233e+00, -1.72302499e-01,  3.80082816e-01,
# ...

# %%
alpha.shape
# Out:
# TensorShape([1, 1, 1, 32])

# %%
alpha
# Out:
# <tf.Tensor: shape=(1, 1, 1, 32), dtype=float32, numpy=
# array([[[[ 0.10963849,  0.10314579,  0.22634086, 18.4899    ,
#            0.1949603 ,  0.09603638,  0.32295808,  8.025716  ,
#            0.16579953,  0.16577041,  0.12513469,  1.5417764 ,
#           19.590965  , 20.824562  ,  0.10010293,  0.11848979,
#            4.1989236 ,  0.14698507,  1.1974407 , 25.109558  ,
#            0.04843626,  0.10568715,  0.3388922 ,  0.09340779,
#            0.07629511,  0.26300952, -0.20090102,  0.09004723,
#            1.1100543 ,  0.66884154,  0.2641704 ,  0.4004299 ]]]],
#       dtype=float32)>

# %%
a = tf.constant([[1,1],[2,2],[3,4]])

# %%
a
# Out:
# <tf.Tensor: shape=(3, 2), dtype=int32, numpy=
# array([[1, 1],
#        [2, 2],
#        [3, 4]], dtype=int32)>

# %%
b = tf.constant([[2,1]])

# %%
b
# Out:
# <tf.Tensor: shape=(1, 2), dtype=int32, numpy=array([[2, 1]], dtype=int32)>

# %%
a * b
# Out:
# <tf.Tensor: shape=(3, 2), dtype=int32, numpy=
# array([[2, 1],
#        [4, 2],
#        [6, 4]], dtype=int32)>

# %%
weight_tensor.shape
# Out:
# TensorShape([1, 3, 3, 32])

# %%
alpha.shape
# Out:
# TensorShape([1, 1, 1, 32])

# %%
alpha
# Out:
# <tf.Tensor: shape=(1, 1, 1, 32), dtype=float32, numpy=
# array([[[[ 0.10963849,  0.10314579,  0.22634086, 18.4899    ,
#            0.1949603 ,  0.09603638,  0.32295808,  8.025716  ,
#            0.16579953,  0.16577041,  0.12513469,  1.5417764 ,
#           19.590965  , 20.824562  ,  0.10010293,  0.11848979,
#            4.1989236 ,  0.14698507,  1.1974407 , 25.109558  ,
#            0.04843626,  0.10568715,  0.3388922 ,  0.09340779,
#            0.07629511,  0.26300952, -0.20090102,  0.09004723,
#            1.1100543 ,  0.66884154,  0.2641704 ,  0.4004299 ]]]],
#       dtype=float32)>

# %%
weight_tensor[0,0,1,:] * alpha
# Out:
# <tf.Tensor: shape=(1, 1, 1, 32), dtype=float32, numpy=
# array([[[[-7.7916443e-01,  3.7005296e-01, -2.7372789e-01,
#           -5.4632492e+01, -4.6250179e-01,  5.1435359e-02,
#           -2.5567520e-01, -7.7607079e+00,  6.3176101e-01,
#            1.9351414e-01, -2.1561021e-02,  5.8600271e-01,
#           -1.1938032e+01, -1.1076800e+01, -1.2729524e-01,
#           -1.2315797e-01, -4.8657784e+00, -5.3255524e-02,
#           -1.0328590e+00,  2.4162693e+01, -4.2303052e-02,
#           -1.2452856e+00,  3.6716223e-01,  1.8091552e-01,
#           -1.9573931e+00, -2.0342417e+00, -3.8823951e-02,
#            3.5917014e-01,  5.5014735e-01,  2.1783974e+00,
#           -3.6086950e-01,  3.1154159e-01]]]], dtype=float32)>

# %%
weight_tensor[0,0,0,0] * alpha[0,0,0,0]
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=-0.10034772>

# %%
weight_tensor[0,0,0,0]
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=-0.91525996>

# %%
from torch import nn

# %%
m = nn.AvgPool2d(7, stride=1)

# %%
 i = torch.randn(1, 1280, 7, 7)

# %%
output = m(i)

# %%
output.shape
# Out:
# torch.Size([1, 1280, 1, 1])

# %% [markdown]
# ### load tflite

# %%
import numpy as np

# %%
inter = tf.lite.Interpreter(model_path = "/Users/bob/code/ByteDance/PNN/resource/models/mobilenet_v2_1.0_224.tflite")

# %%
inter.allocate_tensors()

# %%
input_details = inter.get_input_details()

# %%
outout_details = inter.get_output_details()

# %%
input_shape = input_details[0]['shape']

# %%
input_data = np.array(np.random.random_sample(input_shape),dtype=np.float32)

# %%
input_data.flatten().tofile("/Users/bob/code/ByteDance/PNN/resource/models/test_random_input_1_224_224_3.bin")

# %%
inter.set_tensor(input_details[0]['index'], input_data)

# %%
inter.invoke()

# %%
output_data = inter.get_tensor(outout_details[0]['index'])

# %%
output_data.flatten().tofile("/Users/bob/code/ByteDance/PNN/resource/models/test_standard_output.bin")

# %%
input_data.flatten()
# Out:
# array([0.63374734, 0.97214967, 0.2874241 , ..., 0.6608173 , 0.08425715,
#        0.6965691 ], dtype=float32)

# %%
output_data.flatten()
# Out:
# array([1.2897396e-05, 8.4614248e-06, 2.1369009e-05, ..., 6.3716388e-06,
#        2.8654251e-06, 1.8185686e-04], dtype=float32)

# %%
import tensorflow as tf

# %%
model = tf.keras.Sequential()

# %%
model.add(tf.keras.layers.Dense(32, input_shape=(500,)))

# %%
model.add(tf.keras.layers.BatchNormalization())

# %%
model.layers[1].get_weights()[3].shape
# Out:
# (32,)

# %%
print(tf.__version__)
# Out:
# 2.4.0

# %%
tf.compat.v1.lite.TFLiteConverter.from_frozen_graph("/Users/bob/Desktop/deepfm.pb",["l1","l2","l3"],[])
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# /opt/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/framework/importer.py in _import_graph_def_internal(graph_def, input_map, return_elements, validate_colocation_constraints, name, producer_op_list)
#     495       try:
# --> 496         results = c_api.TF_GraphImportGraphDefWithResults(
#     497             graph._c_graph, serialized, options)  # pylint: disable=protected-access
#
# InvalidArgumentError: Input 1 of node embedding/embedding_lookup was passed float from C1:0 incompatible with expected int32.
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-e1a8641aa2c8> in <module>
# ...

# %%
a = b'\x80abc'

# %%
type(a)
# Out:
# bytes

# %%
a.
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-13-4d564cbc5fe7> in <module>
# ----> 1 a.decode()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x80 in position 0: invalid start byte
