# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.nn.init as init
import numpy as np

# %%
class NetA(nn.Module):
    def __init__(self, *args, **kwargs):
        super(NetA, self).__init__(*args, **kwargs)
        self.conv2d = nn.Conv2d(6,3,3,1)
    
    def forward(self, x):
        return self.conv2d(x)

# %%
class NetB(nn.Module):
    def __init__(self, *args, **kwargs):
        super(NetB, self).__init__(*args, **kwargs)
    def forward(self, x, w, b=None):
        x = F.conv2d(x, w, 
                     bias = b, 
                     stride=1, 
                     padding=(w.size()[2] // 2, w.size()[3] // 2),
                     groups = w.size()[0])
        
        return x

# %%
net_a = NetA()

# %%
inp = torch.rand(1,6,7,7) # 1, 6, 7, 7

# %%
inp.size()
# Out:
# torch.Size([1, 6, 7, 7])

# %%
w = net_a(inp) # 1, 3, 5, 5

# %%
b_input = torch.rand(1,3,25,25)

# %%
net_b = NetB()

# %%
output = net_b(b_input, w)

# %%
output.shape
# Out:
# torch.Size([1, 1, 25, 25])

# %%
# export net_a onnx

torch.onnx.export(net_a,
                 inp,
                  "weight.onnx",
                 export_params = True,
                 input_names = ["data_a"],
                  output_names = ["weight"],
                  opset_version = 9,
                  verbose = True
                 )
# Out:
# graph(%data_a : Float(1, 6, 7, 7, strides=[294, 49, 7, 1], requires_grad=0, device=cpu),
#       %conv2d.weight : Float(3, 6, 3, 3, strides=[54, 9, 3, 1], requires_grad=1, device=cpu),
#       %conv2d.bias : Float(3, strides=[1], requires_grad=1, device=cpu)):
#   %weight : Float(1, 3, 5, 5, strides=[75, 25, 5, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[0, 0, 0, 0], strides=[1, 1]](%data_a, %conv2d.weight, %conv2d.bias) # /opt/anaconda3/envs/tf2/lib/python3.8/site-packages/torch/nn/modules/conv.py:395:0
#   return (%weight)

# %%
# export  net_b onnx
torch.onnx.export(net_b,
                 (b_input,w),
                 "second.onnx",
                  export_params = True,
                 input_names = ["data_b", "weight"],
                  output_names = ["result"],
                  opset_version = 9,
                  verbose = True)
# Out:
# graph(%data_b : Float(1, 3, 25, 25, strides=[1875, 625, 25, 1], requires_grad=0, device=cpu),
#       %weight : Float(1, 3, 5, 5, strides=[75, 25, 5, 1], requires_grad=1, device=cpu)):
#   %result : Float(1, 1, 25, 25, strides=[625, 625, 25, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[5, 5], pads=[2, 2, 2, 2], strides=[1, 1]](%data_b, %weight) # <ipython-input-21-39130c03685a>:5:0
#   return (%result)

# %%
# export net_a weights

# %%
a_nhwc_weight = net_a.conv2d.weight.detach().permute(0,2,3,1).flatten().numpy()

# %%
a_bias = net_a.conv2d.bias.detach().flatten().numpy()

# %%
np.concatenate((a_nhwc_weight,a_bias)).tofile("./a_weight.bin")

# %%
a_input = inp.permute(0,2,3,1).flatten().numpy()

# %%
w.permute(0,2,3,1).flatten()
# Out:
# tensor([ 0.4684,  0.3819,  0.2101,  0.6987,  0.4790,  0.1251,  0.8746,  0.8312,
#          0.0488,  0.7421,  0.4958, -0.0594,  0.6784,  0.5604, -0.0710,  0.4312,
#          0.2661,  0.4668,  0.4594,  0.2708,  0.1293,  0.9763,  0.4617,  0.4410,
#          0.8330,  0.1306,  0.1065,  0.8635,  0.3693,  0.0995,  0.3490,  0.2730,
#         -0.1319,  0.5298,  0.4553,  0.0352,  0.3478,  1.0269,  0.2782,  0.5578,
#          0.5782, -0.1251,  0.8220,  0.3656,  0.1171,  0.5863,  0.0890,  0.0046,
#          0.7409,  0.3795,  0.1152,  0.6472,  0.3727,  0.1081,  0.6846,  0.4498,
#         -0.1167,  0.5570,  0.8083,  0.0186,  0.9817,  0.1612,  0.1780,  0.8837,
#          0.5998, -0.3016,  0.8461,  0.3865,  0.1922,  0.8019,  0.4230,  0.3784,
#          0.9045,  0.1809,  0.2087], grad_fn=<UnsafeViewBackward>)

# %%
# export net_b

# %%
nhwc_b_inut = b_input.permute(0,2,3,1).flatten().numpy()

# %%
b_weight = torch.ones(1,5,5,3).flatten()

# %%
b_bias = torch.zeros(1)

# %%
b_weight = torch.cat([b_weight, b_bias])

# %%
b_weight.numpy().tofile("./b_weight.bin")

# %%
w.numel()
# Out:
# 75

# %%
nhwc_b_inut
# Out:
# array([0.11124557, 0.44433403, 0.71581495, ..., 0.68074006, 0.47817773,
#        0.33011162], dtype=float32)

# %%
F.conv2d(b_input, b_weight[0:75].reshape(1,3,5,5), 
                     bias = b_bias, 
                     stride=1, 
                     padding=(w.size()[2] // 2, w.size()[3] // 2),
                     groups = w.size()[0])
# Out:
# tensor([[[[13.2039, 17.3155, 21.2508, 21.4130, 20.4439, 21.0159, 22.5136,
#            23.6964, 23.1346, 23.3245, 23.9254, 23.5003, 22.6746, 23.5389,
#            25.0276, 24.5513, 24.1395, 23.3710, 23.1418, 23.2321, 23.8614,
#            21.6710, 22.1601, 17.1830, 11.3562],
#           [18.4159, 24.2534, 30.3783, 28.9970, 28.1604, 27.8122, 28.4823,
#            29.2159, 28.8141, 29.3912, 29.5282, 29.7866, 28.0009, 29.1255,
#            30.7994, 30.6945, 30.9680, 31.0421, 30.9758, 30.9517, 31.5158,
#            28.1393, 28.1058, 21.9343, 14.4457],
#           [24.2239, 30.9239, 37.9786, 34.8496, 34.7190, 33.4696, 35.0866,
#            36.9785, 37.7242, 37.6526, 37.9095, 37.7166, 35.2436, 36.1735,
#            37.6385, 38.4818, 38.7949, 39.4045, 39.3030, 38.9407, 38.8848,
#            36.3974, 35.9715, 28.2949, 19.8906],
#           [25.2019, 33.1748, 41.2283, 37.8031, 36.7260, 35.3983, 35.5188,
#            36.1904, 36.6772, 36.9401, 37.9389, 38.0075, 35.6485, 36.6654,
#            38.5151, 38.9053, 40.3946, 40.3721, 40.3400, 39.1537, 38.7462,
#            34.7531, 35.1617, 27.3679, 19.6317],
#           [23.3551, 31.3909, 40.5793, 36.7733, 36.4921, 34.5440, 33.9710,
#            32.2036, 33.3112, 32.9937, 34.3327, 35.5221, 34.0333, 34.9748,
#            37.4864, 38.6670, 39.5084, 39.9057, 39.9202, 39.9802, 39.7810,
#            37.0194, 37.8251, 30.1534, 21.8730],
#           [23.9083, 32.7871, 40.9928, 36.9410, 37.8336, 35.2113, 34.2708,
#            34.5514, 35.6340, 35.7919, 37.0626, 37.3280, 35.3614, 35.4833,
#            36.5215, 37.4814, 38.6617, 39.7998, 40.1349, 40.2873, 40.0789,
#            38.1353, 38.6687, 32.2528, 24.0024],
#           [21.7354, 29.9381, 37.2602, 34.7479, 35.9045, 33.3687, 33.2911,
#            34.1512, 36.0900, 35.9664, 37.8500, 37.7413, 36.7949, 36.4134,
#            37.4655, 38.9499, 39.5483, 40.0191, 40.7937, 40.1201, 39.3146,
#            38.5145, 40.1401, 32.7432, 25.2787],
#           [20.1439, 29.9394, 38.1455, 37.2586, 38.7871, 36.6760, 34.5596,
#            33.5346, 35.3025, 34.1632, 35.8966, 35.6881, 36.1296, 34.6991,
#            36.2067, 36.6852, 38.7386, 38.0950, 39.5448, 39.3457, 40.5273,
#            36.8569, 39.9349, 32.4237, 24.8458],
#           [19.2477, 29.2101, 36.3918, 35.6283, 39.0075, 36.0161, 33.2858,
#            33.5435, 35.3760, 32.8913, 35.6072, 35.8653, 36.5654, 35.1917,
#            36.6672, 36.9305, 37.4100, 36.2247, 37.3929, 37.0815, 37.8981,
#            36.6655, 39.6014, 32.4036, 24.8148],
#           [19.5469, 29.5235, 36.6831, 35.5443, 37.7410, 35.9712, 32.8527,
#            33.6625, 36.0045, 35.0836, 37.3744, 38.1204, 39.2913, 38.3620,
#            38.8187, 39.1648, 38.3008, 36.5138, 35.8140, 36.0208, 35.0532,
#            35.1926, 36.3589, 30.2086, 22.4040],
#           [18.1221, 28.2608, 36.8817, 37.3142, 39.1255, 37.3490, 33.6885,
#            31.8331, 34.0113, 33.3087, 34.7616, 35.0911, 36.9313, 36.1533,
#            38.1704, 40.0211, 40.4920, 39.0431, 37.5178, 36.9041, 34.9594,
#            34.4515, 34.4710, 27.7795, 20.1416],
#           [20.6797, 31.1919, 39.4979, 39.6683, 39.8446, 37.8620, 34.6074,
#            32.9182, 33.4469, 33.0822, 34.0150, 33.9531, 36.2449, 36.4565,
#            38.9921, 40.5706, 40.5434, 38.9230, 37.3447, 36.9450, 35.6334,
#            35.0147, 34.4117, 28.2015, 19.9148],
#           [20.1778, 30.6453, 38.3140, 39.0210, 37.5259, 36.1987, 34.1246,
#            33.7077, 32.6168, 34.9383, 35.1624, 33.8476, 34.8822, 36.6570,
#            38.1955, 40.5846, 40.2570, 39.3056, 36.9318, 37.2048, 34.3633,
#            34.8596, 33.0642, 27.4053, 18.5317],
#           [21.4546, 31.5122, 38.5518, 39.7890, 37.3858, 36.4023, 35.7092,
#            34.8897, 33.9077, 37.2541, 35.6657, 32.8224, 34.5777, 35.8099,
#            36.2386, 38.9819, 40.5332, 40.3723, 38.8984, 39.5077, 37.9294,
#            36.6335, 34.3698, 27.7516, 18.9552],
#           [23.6719, 32.8509, 39.5085, 39.7141, 37.6274, 36.2523, 36.7883,
#            36.0851, 35.5335, 38.0601, 35.5730, 32.4938, 33.5903, 34.4286,
#            33.9103, 35.3218, 38.0704, 38.4309, 38.4821, 38.2637, 39.1750,
#            36.3374, 34.7368, 27.0890, 19.8144],
#           [25.3321, 34.3834, 40.1137, 40.0489, 37.0698, 36.4047, 38.0181,
#            39.2653, 37.8256, 40.2625, 36.8860, 33.6343, 34.2228, 36.1599,
#            34.1408, 34.5601, 36.4251, 37.2566, 37.4124, 38.0415, 40.8459,
#            38.1715, 36.2063, 28.4634, 21.4170],
#           [24.6209, 33.7063, 40.3015, 39.8181, 37.9347, 37.3692, 39.1847,
#            40.4650, 40.3089, 43.2779, 40.8943, 37.3428, 36.7325, 36.8462,
#            33.8479, 32.9986, 35.5302, 36.5748, 36.9994, 37.2578, 39.9187,
#            37.1583, 34.7429, 27.0471, 20.9571],
#           [26.0973, 33.7951, 40.4843, 40.1574, 39.6674, 38.1332, 40.2414,
#            41.6581, 39.9900, 41.0756, 39.7534, 38.0171, 36.8363, 37.3462,
#            35.7683, 33.8646, 35.6743, 36.5304, 38.0777, 37.5343, 39.8343,
#            37.1043, 35.0410, 26.4193, 20.1814],
#           [25.6218, 33.0707, 39.4842, 38.2022, 37.7385, 35.6422, 37.4853,
#            39.8691, 38.5196, 38.6458, 37.6484, 36.7700, 35.2595, 37.4848,
#            37.1309, 35.2153, 35.6273, 36.1158, 35.9169, 35.1945, 37.2214,
#            36.0206, 33.7687, 25.8380, 19.8710],
#           [24.4292, 31.6318, 36.7872, 36.4628, 37.0016, 34.6490, 36.8558,
#            42.0612, 39.5102, 39.1828, 39.0700, 37.3859, 34.0893, 37.3560,
#            37.7400, 35.6694, 36.3064, 36.6322, 36.1696, 34.7024, 36.7388,
#            35.8405, 34.4817, 26.5093, 20.6251],
#           [24.5310, 30.4123, 36.7901, 36.0483, 37.2470, 33.4226, 35.8550,
#            38.5868, 37.1320, 37.8482, 38.4288, 37.7624, 35.1529, 37.1984,
#            37.3796, 36.9630, 38.1180, 38.1276, 37.9897, 36.4599, 36.3128,
#            34.5796, 35.2374, 27.2128, 20.6204],
#           [22.9383, 29.1008, 34.4808, 34.7419, 35.3425, 32.5931, 34.7635,
#            37.4257, 35.4099, 36.5320, 35.7891, 35.2379, 34.2305, 37.9227,
#            38.8840, 40.0833, 40.6691, 39.9531, 37.7243, 36.5794, 36.8487,
#            35.1972, 35.9771, 28.7553, 21.4777],
#           [21.8662, 28.4858, 35.0291, 35.4541, 35.5565, 33.3769, 35.5973,
#            36.3160, 36.9198, 39.0341, 38.7983, 37.7427, 37.6841, 39.9284,
#            39.7706, 40.4707, 40.5416, 40.5292, 37.0659, 36.2442, 37.2627,
#            35.9788, 36.4289, 29.5579, 22.3808],
#           [17.5538, 22.5066, 28.4571, 29.4998, 29.3950, 27.9349, 30.0981,
#            29.7685, 30.0651, 32.6726, 32.1424, 31.1703, 30.8897, 31.5469,
#            30.9577, 32.0962, 32.5482, 32.5341, 30.6666, 29.9984, 30.7048,
#            28.8337, 30.1400, 24.3994, 18.3697],
#           [12.6141, 16.6961, 22.2522, 23.4286, 22.8607, 21.8885, 23.1697,
#            20.8748, 22.0546, 24.7010, 24.2970, 24.0505, 24.9707, 24.2437,
#            23.5749, 25.2715, 24.9257, 25.3900, 23.7290, 23.8239, 23.5232,
#            22.2886, 22.7511, 18.7437, 13.4730]]]])

# %%
output
# Out:
# tensor([[[[ 5.4961,  6.8551,  8.3747,  8.7307,  8.5264,  9.6899,  9.5749,
#             9.6173,  9.1007,  9.4329,  9.5412,  8.3283,  8.9312,  8.3385,
#            10.0003, 10.5802,  9.7305,  9.6543,  9.8884,  9.9378,  9.2975,
#             9.7990, 10.0263,  6.6547,  4.5719],
#           [ 7.4614, 10.2890, 12.5760, 11.5146, 11.6665, 11.1385, 11.7131,
#            12.2821, 12.4094, 12.6501, 11.7847, 11.4821, 10.2969, 11.3709,
#            11.9165, 13.0318, 13.0865, 12.9180, 13.2160, 12.7111, 11.5527,
#            12.0262, 11.1488,  8.2633,  5.7773],
#           [10.3200, 13.6143, 15.2815, 14.0160, 14.6831, 14.7817, 15.0078,
#            15.6305, 16.1564, 15.5633, 15.0553, 13.9882, 13.6277, 14.1233,
#            15.4279, 16.0757, 16.5630, 15.5966, 17.3684, 17.0856, 15.8438,
#            16.2632, 15.1762, 10.2496,  8.2386],
#           [10.7912, 14.9201, 16.8964, 16.6248, 15.8041, 14.4866, 14.5298,
#            16.1584, 14.5442, 15.2655, 13.7464, 13.8273, 12.8672, 14.8791,
#            16.1083, 17.3394, 17.9928, 16.1027, 17.4420, 16.9607, 16.6065,
#            15.5121, 15.1404, 10.4701,  7.7145],
#           [10.4832, 13.8863, 16.9891, 14.9807, 14.8549, 14.1102, 14.3118,
#            13.1246, 13.0947, 14.0224, 13.5134, 13.1221, 13.8095, 14.9565,
#            15.7811, 16.9549, 17.0614, 16.5052, 17.2441, 17.2610, 16.9943,
#            16.2238, 16.3403, 11.9991,  8.7429],
#           [11.2291, 14.0743, 17.4912, 15.2758, 14.9352, 13.6664, 14.1905,
#            14.6208, 14.5659, 15.0117, 15.2583, 15.5365, 15.0552, 16.0157,
#            17.2568, 17.5746, 17.5525, 16.3818, 17.3956, 17.9407, 16.3808,
#            16.4755, 16.3988, 13.1873,  9.1237],
#           [ 9.7003, 12.3570, 15.1394, 14.7044, 13.3196, 11.9481, 12.7024,
#            13.6453, 14.6127, 15.1084, 15.4720, 15.2713, 16.0765, 15.7167,
#            15.3310, 16.9635, 16.9624, 18.4034, 18.8689, 17.2974, 15.7037,
#            15.0615, 16.2291, 12.8426, 10.0411],
#           [ 9.4537, 12.8557, 16.0111, 15.7762, 15.3565, 14.6041, 14.1623,
#            13.7666, 14.0812, 14.2533, 15.3675, 15.0458, 16.4147, 15.9804,
#            16.1678, 15.3057, 16.4790, 16.5934, 17.1845, 17.3865, 17.6434,
#            16.1013, 16.7570, 12.7579, 10.5756],
#           [ 8.5324, 12.2564, 15.1278, 15.2519, 15.9174, 14.4816, 14.3728,
#            13.5644, 14.4659, 13.5860, 14.3299, 16.2152, 15.7992, 15.9909,
#            17.1461, 16.3607, 17.2257, 16.7605, 16.3439, 16.0740, 16.0596,
#            15.1319, 16.6938, 13.3098, 10.2552],
#           [ 8.4479, 12.7753, 15.3573, 15.5182, 15.4821, 13.0273, 13.3672,
#            13.2162, 13.4955, 14.4782, 15.2873, 14.9260, 15.2185, 16.5210,
#            17.5541, 17.3713, 16.9082, 16.4727, 14.7199, 14.4960, 13.6944,
#            12.7454, 15.2246, 11.6262,  8.4736],
#           [ 8.3244, 12.0945, 14.9290, 16.4528, 16.3488, 15.3520, 14.1417,
#            12.2725, 13.3869, 12.6771, 13.8208, 13.8817, 14.7496, 13.1172,
#            15.2253, 16.0308, 16.7499, 16.2862, 16.0097, 15.6648, 14.6571,
#            14.3114, 15.5148, 11.9736, 10.0461],
#           [ 9.8746, 13.2359, 15.8073, 16.5163, 16.3252, 15.0696, 13.6888,
#            13.7291, 14.6563, 14.0281, 13.6858, 13.3085, 14.3756, 14.8429,
#            17.4973, 17.5067, 16.7024, 15.3492, 15.1676, 15.6168, 14.6560,
#            14.4389, 14.6861, 12.0877,  8.6362],
#           [ 9.2206, 13.6129, 16.4130, 16.7324, 15.7761, 14.0318, 13.3219,
#            13.8356, 12.5992, 14.0173, 13.4559, 13.5132, 13.5340, 14.0399,
#            16.3071, 17.7641, 16.7797, 16.4852, 14.4165, 16.0461, 14.0808,
#            15.1693, 13.5324, 11.2496,  7.5919],
#           [ 9.4928, 12.9359, 15.6975, 16.1633, 15.1071, 14.8152, 14.3469,
#            13.8056, 14.4702, 14.3868, 13.2995, 12.4579, 14.4592, 14.5215,
#            14.9769, 16.7352, 17.4384, 16.6267, 15.8034, 17.0224, 15.5765,
#            15.3954, 13.0898, 10.8861,  7.0252],
#           [11.5676, 15.2759, 16.6694, 16.6481, 15.3738, 14.5943, 15.8002,
#            14.8272, 15.1909, 15.3118, 13.9822, 12.5043, 12.9222, 12.7404,
#            12.8951, 13.5436, 15.6332, 15.5115, 16.6988, 16.1824, 17.0717,
#            16.1462, 14.3512, 10.6351,  7.4477],
#           [11.5448, 15.4586, 16.4986, 17.5249, 15.5644, 15.3670, 16.6290,
#            17.7386, 16.8156, 16.6943, 14.2043, 13.8037, 13.5645, 13.7018,
#            12.3974, 13.1233, 15.0858, 15.4469, 15.7793, 15.6901, 15.5212,
#            13.8013, 13.4944, 11.2831,  8.8192],
#           [11.4739, 14.8657, 17.6160, 16.1081, 16.2658, 15.3907, 15.6337,
#            16.9489, 17.2691, 17.5896, 16.5438, 14.6591, 13.9945, 13.9667,
#            12.3038, 12.0540, 14.5340, 15.3869, 16.1740, 15.4290, 16.9243,
#            14.7294, 12.9176, 10.1896,  7.5763],
#           [11.8622, 16.1093, 17.1572, 17.2652, 16.7545, 15.7964, 16.5646,
#            17.9570, 16.5072, 16.0791, 14.9041, 14.5013, 13.3553, 13.1521,
#            12.8285, 12.6675, 14.3931, 15.6818, 16.1152, 14.7964, 15.5180,
#            13.8913, 14.4810, 11.4191,  8.3000],
#           [11.9969, 15.0470, 16.4545, 16.0138, 13.3631, 13.5853, 14.0865,
#            16.3660, 16.5159, 16.4045, 14.5690, 14.3979, 13.8240, 15.0037,
#            13.8938, 12.9130, 13.9435, 14.4108, 14.3482, 14.4850, 14.5531,
#            14.4222, 13.3866, 10.3780,  7.8180],
#           [11.0684, 14.0868, 15.4221, 14.3895, 15.0812, 14.1637, 14.7695,
#            17.5541, 17.0692, 16.1605, 15.0466, 13.4988, 13.1730, 15.1448,
#            15.3895, 13.6334, 15.0966, 14.1028, 14.5346, 12.9330, 14.4016,
#            14.2027, 14.3271, 11.1022,  8.4772],
#           [11.1786, 12.3860, 15.3160, 14.3385, 13.6563, 13.1221, 15.3898,
#            15.5245, 15.9084, 16.8445, 15.7400, 14.5346, 13.9563, 15.3001,
#            14.2570, 14.8713, 15.0771, 15.0505, 15.4147, 14.9892, 14.8748,
#            13.3688, 13.6077, 11.3941,  7.9760],
#           [10.2810, 11.8021, 13.4469, 13.9001, 12.2130, 12.9653, 14.1712,
#            15.2054, 15.1123, 15.8206, 15.0092, 14.0783, 14.8731, 15.6388,
#            15.0636, 16.5394, 16.2991, 15.7262, 15.5342, 14.8746, 16.2486,
#            14.9410, 14.9498, 12.0590,  8.8593],
#           [ 9.9710, 11.2074, 14.0882, 14.5853, 14.5327, 14.0247, 14.4738,
#            14.8572, 14.9754, 17.2245, 15.3613, 15.6213, 16.0405, 16.1897,
#            16.2133, 16.8631, 16.8701, 17.3798, 14.7990, 14.4087, 15.5830,
#            14.0087, 14.6236, 11.2361,  9.2346],
#           [ 7.9318,  9.7829, 11.6663, 11.4022, 12.0341, 11.5805, 13.1809,
#            12.4533, 12.7807, 14.1676, 13.2192, 12.7143, 11.7001, 12.7235,
#            12.3079, 13.2324, 13.7549, 13.6277, 12.0310, 11.8982, 11.7433,
#            11.3835, 11.8763,  9.3817,  7.3198],
#           [ 5.6608,  7.1132,  9.2989,  9.9825,  9.1488,  9.4206,  9.5937,
#             8.6286,  9.1826, 10.4170, 10.4799, 10.3204, 10.4194,  9.6779,
#             9.0324, 10.3513, 11.3072, 11.3935, 10.4386, 10.0070,  9.5759,
#             9.1372,  9.6912,  7.3827,  5.6719]]]],
#        grad_fn=<MkldnnConvolutionBackward>)
